# %%
family = {
    
        'firstName' : ['vijaya' , 'ram' , 'siva'],
        'lastName' : ['lakshmi' , 'prasad' , 'parvathi'],
        'email' : ['vijaya.lakshmi@gmail.com' , 'ram.prasad@gmail.com' , 'siva.parvathi@gmail.com']
}

# %%
import pandas as pd

family_df = pd.DataFrame(family)

# %%
family_df
# Out:
#   firstName  lastName                     email
# 0    vijaya   lakshmi  vijaya.lakshmi@gmail.com
# 1       ram    prasad      ram.prasad@gmail.com
# 2      siva  parvathi   siva.parvathi@gmail.com

# %%
family_df['email']
# Out:
# 0    vijaya.lakshmi@gmail.com
# 1        ram.prasad@gmail.com
# 2     siva.parvathi@gmail.com
# Name: email, dtype: object

# %%
family_df.set_index('email')
# Out:
#                          firstName  lastName
# email
# vijaya.lakshmi@gmail.com    vijaya   lakshmi
# ram.prasad@gmail.com           ram    prasad
# siva.parvathi@gmail.com       siva  parvathi

# %%
family_df
# Out:
#   firstName  lastName                     email
# 0    vijaya   lakshmi  vijaya.lakshmi@gmail.com
# 1       ram    prasad      ram.prasad@gmail.com
# 2      siva  parvathi   siva.parvathi@gmail.com

# %%
family_df.set_index('email' , inplace = True)

# %%
family_df
# Out:
#                          firstName  lastName
# email
# vijaya.lakshmi@gmail.com    vijaya   lakshmi
# ram.prasad@gmail.com           ram    prasad
# siva.parvathi@gmail.com       siva  parvathi

# %%
family_df.index
# Out:
# Index(['vijaya.lakshmi@gmail.com', 'ram.prasad@gmail.com',
#        'siva.parvathi@gmail.com'],
#       dtype='object', name='email')

# %%
family_df.loc['ram.prasad@gmail.com']
# Out:
# firstName       ram
# lastName     prasad
# Name: ram.prasad@gmail.com, dtype: object

# %%
family_df.reset_index(inplace=True)

# %%
family_df.index
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
family_df
# Out:
#                       email firstName  lastName
# 0  vijaya.lakshmi@gmail.com    vijaya   lakshmi
# 1      ram.prasad@gmail.com       ram    prasad
# 2   siva.parvathi@gmail.com      siva  parvathi

# %%
import pandas as pd

survey_df = pd.read_csv('data/survey_results_public_2019.csv' , index_col='Respondent')
survey_schema_df = pd.read_csv('data/survey_results_schema_2019.csv' , index_col='Column')

# %%
pd.set_option('display.max_columns' , 85)
pd.set_option('display.max_rows' , 85)

# %%
survey_df.head(2)
# Out:
#                                         MainBranch Hobbyist  \
# Respondent
# 1           I am a student who is learning to code      Yes
# 2           I am a student who is learning to code       No
#
#                         OpenSourcer  \
# Respondent
# 1                             Never
# 2           Less than once per year
#
#                                                    OpenSource  \
# Respondent
# 1           The quality of OSS and closed source software ...
# 2           The quality of OSS and closed source software ...
#
#                                         Employment                 Country  \
# Respondent
# 1           Not employed, and not looking for work          United Kingdom
# 2               Not employed, but looking for work  Bosnia and Herzegovina
#
#                    Student                                            EdLevel  \
# Respondent
# 1                       No                          Primary/elementary school
# ...

# %%
survey_schema_df.head()
# Out:
#                                                   QuestionText
# Column
# Respondent   Randomized respondent ID number (not in order ...
# MainBranch   Which of the following options best describes ...
# Hobbyist                               Do you code as a hobby?
# OpenSourcer        How often do you contribute to open source?
# OpenSource   How do you feel about the quality of open sour...

# %%
survey_schema_df.loc['Hobbyist']
# Out:
# QuestionText    Do you code as a hobby?
# Name: Hobbyist, dtype: object

# %%
survey_schema_df.loc['MgrIdiot']
# Out:
# QuestionText    How confident are you that your manager knows ...
# Name: MgrIdiot, dtype: object

# %%
survey_schema_df.loc['MgrIdiot','QuestionText']
# Out:
# 'How confident are you that your manager knows what they’re doing?'

# %%
survey_schema_df.sort_index()
# Out:
#                                                              QuestionText
# Column
# Age                     What is your age (in years)? If you prefer not...
# Age1stCode              At what age did you write your first line of c...
# BetterLife              Do you think people born today will have a bet...
# BlockchainIs            Blockchain / cryptocurrency technology is prim...
# BlockchainOrg           How is your organization thinking about or imp...
# CareerSat               Overall, how satisfied are you with your caree...
# CodeRev                          Do you review code as part of your work?
# CodeRevHrs              On average, how many hours per week do you spe...
# CompFreq                 Is that compensation weekly, monthly, or yearly?
# CompTotal               What is your current total compensation (salar...
# Containers              How do you use containers (Docker, Open Contai...
# ConvertedComp           Salary converted to annual USD salaries using ...
# ...

# %%
survey_schema_df.sort_index(inplace = True)

# %%
survey_schema_df
# Out:
#                                                              QuestionText
# Column
# Age                     What is your age (in years)? If you prefer not...
# Age1stCode              At what age did you write your first line of c...
# BetterLife              Do you think people born today will have a bet...
# BlockchainIs            Blockchain / cryptocurrency technology is prim...
# BlockchainOrg           How is your organization thinking about or imp...
# CareerSat               Overall, how satisfied are you with your caree...
# CodeRev                          Do you review code as part of your work?
# CodeRevHrs              On average, how many hours per week do you spe...
# CompFreq                 Is that compensation weekly, monthly, or yearly?
# CompTotal               What is your current total compensation (salar...
# Containers              How do you use containers (Docker, Open Contai...
# ConvertedComp           Salary converted to annual USD salaries using ...
# ...
