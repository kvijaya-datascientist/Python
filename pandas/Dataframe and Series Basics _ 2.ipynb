# %%
import pandas as pd

# %%
survey_df = pd.read_csv('data/survey_results_public_2019.csv')

# %%
survey_schema_df = pd.read_csv('data/survey_results_schema_2019.csv')

# %%
pd.set_option('display.max_columns' , 85)

pd.set_option('display.max_rows' , 85)

# %%
survey_df.head(2)
# Out:
#    Respondent                              MainBranch Hobbyist  \
# 0           1  I am a student who is learning to code      Yes
# 1           2  I am a student who is learning to code       No
#
#                OpenSourcer                                         OpenSource  \
# 0                    Never  The quality of OSS and closed source software ...
# 1  Less than once per year  The quality of OSS and closed source software ...
#
#                                Employment                 Country  \
# 0  Not employed, and not looking for work          United Kingdom
# 1      Not employed, but looking for work  Bosnia and Herzegovina
#
#           Student                                            EdLevel  \
# 0              No                          Primary/elementary school
# 1  Yes, full-time  Secondary school (e.g. American high school, G...
#
#   UndergradMajor                                           EduOther OrgSize  \
# ...

# %%
survey_schema_df
# Out:
#                     Column                                       QuestionText
# 0               Respondent  Randomized respondent ID number (not in order ...
# 1               MainBranch  Which of the following options best describes ...
# 2                 Hobbyist                            Do you code as a hobby?
# 3              OpenSourcer        How often do you contribute to open source?
# 4               OpenSource  How do you feel about the quality of open sour...
# 5               Employment  Which of the following best describes your cur...
# 6                  Country          In which country do you currently reside?
# 7                  Student  Are you currently enrolled in a formal, degree...
# 8                  EdLevel  Which of the following best describes the high...
# 9           UndergradMajor  What was your main or most important field of ...
# 10                EduOther  Which of the following types of non-degree edu...
# ...

# %% [markdown]
# # Series

# %%
family = {
           'firstName' : ['vijaya' , 'ram' , 'siva'],
            'lastName' : ['lakshmi' , 'prasad' , 'parvathi'],
            'email' : ['vijaya.lakshmi@gmail.com' , 'ram.prasad@gmail.com' , 'siva.parvathi@gmail.com']
    
}

# %%
family['email']
# Out:
# ['vijaya.lakshmi@gmail.com', 'ram.prasad@gmail.com', 'siva.parvathi@gmail.com']

# %%
family_df = pd.DataFrame(family)

# %%
family_df['email']
# Out:
# 0    vijaya.lakshmi@gmail.com
# 1        ram.prasad@gmail.com
# 2     siva.parvathi@gmail.com
# Name: email, dtype: object

# %%
family_df.email
# Out:
# 0    vijaya.lakshmi@gmail.com
# 1        ram.prasad@gmail.com
# 2     siva.parvathi@gmail.com
# Name: email, dtype: object

# %%
type(family_df['email'])
# Out:
# pandas.core.series.Series

# %%
family_df
# Out:
#   firstName  lastName                     email
# 0    vijaya   lakshmi  vijaya.lakshmi@gmail.com
# 1       ram    prasad      ram.prasad@gmail.com
# 2      siva  parvathi   siva.parvathi@gmail.com

# %%
family_df[['lastName' , 'email']]
# Out:
#    lastName                     email
# 0   lakshmi  vijaya.lakshmi@gmail.com
# 1    prasad      ram.prasad@gmail.com
# 2  parvathi   siva.parvathi@gmail.com

# %%
family_df.columns
# Out:
# Index(['firstName', 'lastName', 'email'], dtype='object')

# %%
family_df.iloc[:1 , :]
# Out:
#   firstName lastName                     email
# 0    vijaya  lakshmi  vijaya.lakshmi@gmail.com

# %%
family_df.loc[:0 , :]
# Out:
#   firstName lastName                     email
# 0    vijaya  lakshmi  vijaya.lakshmi@gmail.com

# %%
family_df.loc[[0]]
# Out:
#   firstName lastName                     email
# 0    vijaya  lakshmi  vijaya.lakshmi@gmail.com

# %%
family_df.iloc[0]
# Out:
# firstName                      vijaya
# lastName                      lakshmi
# email        vijaya.lakshmi@gmail.com
# Name: 0, dtype: object

# %%
family_df.loc[0]
# Out:
# firstName                      vijaya
# lastName                      lakshmi
# email        vijaya.lakshmi@gmail.com
# Name: 0, dtype: object

# %%
family_df.iloc[:2,:]
# Out:
#   firstName lastName                     email
# 0    vijaya  lakshmi  vijaya.lakshmi@gmail.com
# 1       ram   prasad      ram.prasad@gmail.com

# %%
family_df.loc[:1 , :]
# Out:
#   firstName lastName                     email
# 0    vijaya  lakshmi  vijaya.lakshmi@gmail.com
# 1       ram   prasad      ram.prasad@gmail.com

# %%
family_df.loc[[0 , 1]]
# Out:
#   firstName lastName                     email
# 0    vijaya  lakshmi  vijaya.lakshmi@gmail.com
# 1       ram   prasad      ram.prasad@gmail.com

# %%
family_df.iloc[1:2 , :]
# Out:
#   firstName lastName                 email
# 1       ram   prasad  ram.prasad@gmail.com

# %%
family_df.loc[[1]]
# Out:
#   firstName lastName                 email
# 1       ram   prasad  ram.prasad@gmail.com

# %%
family_df.loc[[0,1],'email']
# Out:
# 0    vijaya.lakshmi@gmail.com
# 1        ram.prasad@gmail.com
# Name: email, dtype: object

# %%
family_df.loc[[0,1],['email']]
# Out:
#                       email
# 0  vijaya.lakshmi@gmail.com
# 1      ram.prasad@gmail.com

# %%
family_df.loc[[0,1] , ['email' , 'firstName']]
# Out:
#                       email firstName
# 0  vijaya.lakshmi@gmail.com    vijaya
# 1      ram.prasad@gmail.com       ram

# %%
family_df.iloc[0:2 ,2]
# Out:
# 0    vijaya.lakshmi@gmail.com
# 1        ram.prasad@gmail.com
# Name: email, dtype: object

# %%
survey_df.head(2)
# Out:
#    Respondent                              MainBranch Hobbyist  \
# 0           1  I am a student who is learning to code      Yes
# 1           2  I am a student who is learning to code       No
#
#                OpenSourcer                                         OpenSource  \
# 0                    Never  The quality of OSS and closed source software ...
# 1  Less than once per year  The quality of OSS and closed source software ...
#
#                                Employment                 Country  \
# 0  Not employed, and not looking for work          United Kingdom
# 1      Not employed, but looking for work  Bosnia and Herzegovina
#
#           Student                                            EdLevel  \
# 0              No                          Primary/elementary school
# 1  Yes, full-time  Secondary school (e.g. American high school, G...
#
#   UndergradMajor                                           EduOther OrgSize  \
# ...

# %%
survey_schema_df
# Out:
#                     Column                                       QuestionText
# 0               Respondent  Randomized respondent ID number (not in order ...
# 1               MainBranch  Which of the following options best describes ...
# 2                 Hobbyist                            Do you code as a hobby?
# 3              OpenSourcer        How often do you contribute to open source?
# 4               OpenSource  How do you feel about the quality of open sour...
# 5               Employment  Which of the following best describes your cur...
# 6                  Country          In which country do you currently reside?
# 7                  Student  Are you currently enrolled in a formal, degree...
# 8                  EdLevel  Which of the following best describes the high...
# 9           UndergradMajor  What was your main or most important field of ...
# 10                EduOther  Which of the following types of non-degree edu...
# ...

# %%
survey_df['Hobbyist']
# Out:
# 0        Yes
# 1         No
# 2        Yes
# 3         No
# 4        Yes
#         ...
# 88878    Yes
# 88879     No
# 88880     No
# 88881     No
# 88882    Yes
# Name: Hobbyist, Length: 88883, dtype: object

# %%
sum(survey_df['Hobbyist']=='Yes')
# Out:
# 71257

# %%
sum(survey_df['Hobbyist']=='No')
# Out:
# 17626

# %%
survey_df['Hobbyist'].value_counts()
# Out:
# Yes    71257
# No     17626
# Name: Hobbyist, dtype: int64

# %%
survey_df.iloc[:0 , 2]
# Out:
# Series([], Name: Hobbyist, dtype: object)

# %%
survey_df.loc[[1] , ['Hobbyist','OpenSourcer']]
# Out:
#   Hobbyist              OpenSourcer
# 1       No  Less than once per year

# %%
survey_df.loc[[1] , 'Hobbyist']
# Out:
# 1    No
# Name: Hobbyist, dtype: object

# %%
survey_df.loc[[0,1,2] , 'Hobbyist']
# Out:
# 0    Yes
# 1     No
# 2    Yes
# Name: Hobbyist, dtype: object

# %%
survey_df.loc[0:2 , 'Hobbyist']
# Out:
# 0    Yes
# 1     No
# 2    Yes
# Name: Hobbyist, dtype: object

# %%
survey_df.loc[0:2 , 'Hobbyist' : 'Country']
# Out:
#   Hobbyist              OpenSourcer  \
# 0      Yes                    Never
# 1       No  Less than once per year
# 2      Yes                    Never
#
#                                           OpenSource  \
# 0  The quality of OSS and closed source software ...
# 1  The quality of OSS and closed source software ...
# 2  The quality of OSS and closed source software ...
#
#                                Employment                 Country
# 0  Not employed, and not looking for work          United Kingdom
# 1      Not employed, but looking for work  Bosnia and Herzegovina
# 2                      Employed full-time                Thailand
