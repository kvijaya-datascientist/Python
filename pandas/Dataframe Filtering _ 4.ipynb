# %%
family = {
            'firstName' : ['vijaya' , 'ram' , 'siva'],
            'lastName' : ['lakshmi' , 'prasad' , 'parvathi'],
            'email' : ['vijaya.lakshmi@gmail.com' , 'ram.prasad@gmail.com' , 'siva.parvathi@gmail.com']
    
}

# %%
import pandas as pd

family_df = pd.DataFrame(family)

# %%
family_df
# Out:
#   firstName  lastName                     email
# 0    vijaya   lakshmi  vijaya.lakshmi@gmail.com
# 1       ram    prasad      ram.prasad@gmail.com
# 2      siva  parvathi   siva.parvathi@gmail.com

# %%
family_df['lastName'] == 'prasad'
# Out:
# 0    False
# 1     True
# 2    False
# Name: lastName, dtype: bool

# %%
family_df[family_df['lastName']=='prasad']
# Out:
#   firstName lastName                 email
# 1       ram   prasad  ram.prasad@gmail.com

# %%
family_df.loc[family_df['lastName']=='prasad']
# Out:
#   firstName lastName                 email
# 1       ram   prasad  ram.prasad@gmail.com

# %%
family_df.loc[family_df['lastName']=='prasad' , 'email']
# Out:
# 1    ram.prasad@gmail.com
# Name: email, dtype: object

# %%
#family_df[(family_df['lastName']=='prasad') & (family_df['firstName'] == 'ram')]

filt = (family_df['lastName'] == 'prasad') & (family_df['firstName'] == 'ram')

#family_df[filt]

family_df.loc[filt]
# Out:
#   firstName lastName                 email
# 1       ram   prasad  ram.prasad@gmail.com

# %%
filt = (family_df['lastName'] == 'prasad') | (family_df['firstName'] == 'siva')

family_df[filt]
# Out:
#   firstName  lastName                    email
# 1       ram    prasad     ram.prasad@gmail.com
# 2      siva  parvathi  siva.parvathi@gmail.com

# %%
family_df[-filt]
# Out:
#   firstName lastName                     email
# 0    vijaya  lakshmi  vijaya.lakshmi@gmail.com

# %%
survey_results_df = pd.read_csv('data/survey_results_public_2019.csv')

survey_schema_df = pd.read_csv('data/survey_results_schema_2019.csv')

# %%
pd.set_option('display.max_columns' , 85)
pd.set_option('display.max_rows' , 85)

# %%
survey_results_df.head(2)
# Out:
#    Respondent                              MainBranch Hobbyist  \
# 0           1  I am a student who is learning to code      Yes
# 1           2  I am a student who is learning to code       No
#
#                OpenSourcer                                         OpenSource  \
# 0                    Never  The quality of OSS and closed source software ...
# 1  Less than once per year  The quality of OSS and closed source software ...
#
#                                Employment                 Country  \
# 0  Not employed, and not looking for work          United Kingdom
# 1      Not employed, but looking for work  Bosnia and Herzegovina
#
#           Student                                            EdLevel  \
# 0              No                          Primary/elementary school
# 1  Yes, full-time  Secondary school (e.g. American high school, G...
#
#   UndergradMajor                                           EduOther OrgSize  \
# ...

# %%
survey_results_df[survey_results_df['ConvertedComp'] > 70000]
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 5               6  I am not primarily a developer, but I write co...      Yes
# 8               9                     I am a developer by profession      Yes
# 12             13                     I am a developer by profession      Yes
# 15             16                     I am a developer by profession      Yes
# 21             22                     I am a developer by profession      Yes
# ...           ...                                                ...      ...
# 88323       88876                     I am a developer by profession      Yes
# 88324       88877                     I am a developer by profession      Yes
# 88325       88878                     I am a developer by profession      Yes
# 88326       88879                     I am a developer by profession      Yes
# 88329       88882                     I am a developer by profession      Yes
#
# ...

# %%
survey_results_df.loc[survey_results_df['ConvertedComp'] > 70000 , ['LanguageWorkedWith' , 'Country' , 'ConvertedComp']]
# Out:
#                                       LanguageWorkedWith         Country  \
# 5                                             Java;R;SQL          Canada
# 8      Bash/Shell/PowerShell;C#;HTML/CSS;JavaScript;P...     New Zealand
# 12     Bash/Shell/PowerShell;HTML/CSS;JavaScript;PHP;...   United States
# 15     Bash/Shell/PowerShell;C#;HTML/CSS;JavaScript;T...  United Kingdom
# 21     Bash/Shell/PowerShell;C++;HTML/CSS;JavaScript;...   United States
# ...                                                  ...             ...
# 88323  Bash/Shell/PowerShell;C#;HTML/CSS;Java;Python;...   United States
# 88324  Bash/Shell/PowerShell;C;Clojure;HTML/CSS;Java;...   United States
# 88325               HTML/CSS;JavaScript;Scala;TypeScript   United States
# 88326                   Bash/Shell/PowerShell;C++;Python         Finland
# 88329             C#;HTML/CSS;Java;JavaScript;PHP;Python     Netherlands
#
#        ConvertedComp
# 5           366420.0
# 8            95179.0
# 12           90000.0
# ...

# %%
filt = survey_results_df['Country'].isin(['Canada','United States', 'India'])

survey_results_df.loc[filt , ['Country']]
# Out:
#              Country
# 3      United States
# 5             Canada
# 7              India
# 9              India
# 11            Canada
# ...              ...
# 88855         Canada
# 88859  United States
# 88864          India
# 88877  United States
# 88878         Canada
#
# [33405 rows x 1 columns]

# %%
survey_results_df.loc[survey_results_df['LanguageWorkedWith'].str.contains('Python' , na = False), 'LanguageWorkedWith']
# Out:
# 0                          HTML/CSS;Java;JavaScript;Python
# 1                                      C++;HTML/CSS;Python
# 3                                      C;C++;C#;Python;SQL
# 4              C++;HTML/CSS;Java;JavaScript;Python;SQL;VBA
# 7        Bash/Shell/PowerShell;C;C++;HTML/CSS;Java;Java...
#                                ...
# 88854    Bash/Shell/PowerShell;C;C++;HTML/CSS;Java;Java...
# 88860      Bash/Shell/PowerShell;C++;Python;Ruby;Other(s):
# 88865      Bash/Shell/PowerShell;HTML/CSS;Python;Other(s):
# 88872             C;C++;HTML/CSS;JavaScript;PHP;Python;SQL
# 88876                           HTML/CSS;JavaScript;Python
# Name: LanguageWorkedWith, Length: 36443, dtype: object
